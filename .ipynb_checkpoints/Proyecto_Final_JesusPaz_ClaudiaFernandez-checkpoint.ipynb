# %%
import numpy as np #operaciones matriciales y con vectores
import pandas as pd #tratamiento de datos
import matplotlib.pyplot as plt #gráficos
from sklearn.model_selection import train_test_split #metodo de particionamiento de datasets para evaluación
from sklearn.model_selection import KFold, cross_val_score #protocolo de evaluación
from sklearn import neighbors, datasets, metrics, tree
from sklearn.naive_bayes import  BernoulliNB, GaussianNB, MultinomialNB
from sklearn import preprocessing 
import seaborn as sns
import io
#from google.colab import files
#!pip install PyDrive
import os
#from pydrive.auth import GoogleAuth
#from pydrive.drive import GoogleDrive
#from google.colab import auth
#from oauth2client.client import GoogleCredentials
#from google.colab import drive
import math

# %%
#drive.mount('/gdrive')

# %%
#data = pd.read_csv("/gdrive/My Drive/archivos_analitica/training.tsv",sep="\t")
data = pd.read_csv("training.tsv", sep="\t")
data.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10 ...  \
# 0   NaN   NaN   NaN   NaN   NaN  1526.0   7.0   NaN   NaN    NaN ...
# 1   NaN   NaN   NaN   NaN   NaN   525.0   0.0   NaN   NaN    NaN ...
# 2   NaN   NaN   NaN   NaN   NaN  5236.0   7.0   NaN   NaN    NaN ...
# 3   NaN   NaN   NaN   NaN   NaN     NaN   0.0   NaN   NaN    NaN ...
# 4   NaN   NaN   NaN   NaN   NaN  1029.0   7.0   NaN   NaN    NaN ...
#
#        Var223  Var224  Var225  Var226   Var227         Var228  Var229  Var230  \
# 0  jySVZNlOJy     NaN     NaN    xb3V     RAYp  F2FyR07IdsN7I     NaN     NaN
# 1  LM8l689qOp     NaN     NaN    fKCe     RAYp  F2FyR07IdsN7I     NaN     NaN
# 2  jySVZNlOJy     NaN    kG3k    Qu4f  02N6s8f  ib5G6X1eUxUn6    am7c     NaN
# 3  LM8l689qOp     NaN     NaN    FSa2     RAYp  F2FyR07IdsN7I     NaN     NaN
# 4  LM8l689qOp     NaN    kG3k    FSa2     RAYp  F2FyR07IdsN7I    mj86     NaN
#
#    Conversion  ID
# 0          -1   1
# 1          -1   2
# 2          -1   3
# 3          -1   4
# 4          -1   5
#
# [5 rows x 232 columns]

# %%
ax=sns.countplot(x="Conversion",data=data)

# %%
data.shape[0]
# Out:
# 40053

# %%
data.Conversion[data.Conversion==-1].aggregate('count')/data.shape[0]*100
# Out:
# 92.63975232816519

# %% [markdown]
# Se tiene que el baseline es un modelo que que clasifica a los datos en "-1", con una exactitud de 92.64%

# %% [markdown]
# **Entendimiento de los datos, limpieza**
#
# Se analizará los datos y qué inconsistencias presentan.

# %%
print('Existen ', data.shape, ' número de datos y columnas respectivamente.')
# Out:
# Existen  (40053, 232)  número de datos y columnas respectivamente.

# %%
data.tail()
# Out:
#        Var1  Var2  Var3  Var4  Var5    Var6  Var7  Var8  Var9  Var10  ...    \
# 40048   NaN   NaN   NaN   NaN   NaN  2226.0   7.0   NaN   NaN    NaN  ...
# 40049   NaN   NaN   NaN   NaN   NaN   266.0   0.0   NaN   NaN    NaN  ...
# 40050   NaN   NaN   NaN   NaN   NaN  1078.0   0.0   NaN   NaN    NaN  ...
# 40051   NaN   NaN   NaN   0.0   NaN     NaN   NaN   NaN   NaN    NaN  ...
# 40052   NaN   NaN   NaN   NaN   NaN  1694.0   7.0   NaN   NaN    NaN  ...
#
#            Var223  Var224  Var225  Var226  Var227         Var228  Var229  \
# 40048  LM8l689qOp     NaN     NaN    fKCe    RAYp  F2FyR07IdsN7I     NaN
# 40049  LM8l689qOp     NaN     NaN    xb3V    RAYp  F2FyR07IdsN7I     NaN
# 40050  LM8l689qOp     NaN    kG3k    FSa2    RAYp        55YFVY9    am7c
# 40051  LM8l689qOp     NaN     NaN    FSa2    RAYp  F2FyR07IdsN7I     NaN
# 40052  LM8l689qOp     NaN     NaN    xb3V    RAYp  F2FyR07IdsN7I     NaN
#
#        Var230  Conversion     ID
# 40048     NaN          -1  40049
# 40049     NaN          -1  40050
# 40050     NaN          -1  40051
# 40051     NaN          -1  40052
# 40052     NaN           1  40053
#
# [5 rows x 232 columns]

# %%
data.describe(include="all")
# Out:
#               Var1        Var2           Var3         Var4          Var5  \
# count   549.000000  987.000000     986.000000  1242.000000  1.206000e+03
# unique         NaN         NaN            NaN          NaN           NaN
# top            NaN         NaN            NaN          NaN           NaN
# freq           NaN         NaN            NaN          NaN           NaN
# mean     12.167577    0.005066     473.181542     0.152174  2.352029e+05
# std      45.250975    0.159152    4738.645209     1.414282  6.339295e+05
# min       0.000000    0.000000       0.000000     0.000000  0.000000e+00
# 25%       0.000000    0.000000       0.000000     0.000000  0.000000e+00
# 50%       0.000000    0.000000       0.000000     0.000000  0.000000e+00
# 75%      16.000000    0.000000       0.000000     0.000000  1.111938e+05
# max     680.000000    5.000000  130668.000000    27.000000  6.048000e+06
#
#                  Var6          Var7  Var8         Var9         Var10  \
# count    35641.000000  35649.000000   0.0   549.000000  1.206000e+03
# unique            NaN           NaN   NaN          NaN           NaN
# top               NaN           NaN   NaN          NaN           NaN
# freq              NaN           NaN   NaN          NaN           NaN
# mean      1322.620157      6.803052   NaN    50.539162  4.002348e+05
# std       2620.594097      6.337622   NaN   171.858329  9.572521e+05
# min          0.000000      0.000000   NaN     0.000000  0.000000e+00
# 25%        518.000000      0.000000   NaN     4.000000  0.000000e+00
# 50%        861.000000      7.000000   NaN    20.000000  0.000000e+00
# 75%       1428.000000      7.000000   NaN    46.000000  2.625885e+05
# max     114079.000000    140.000000   NaN  2300.000000  1.232559e+07
#
#             ...           Var223  Var224  Var225  Var226  Var227  \
# count       ...            35885     651   19121   40053   40053
# unique      ...                4       1       3      23       7
# top         ...       LM8l689qOp    4n2X    ELof    FSa2    RAYp
# freq        ...            29314     651    8885    6387   28177
# mean        ...              NaN     NaN     NaN     NaN     NaN
# std         ...              NaN     NaN     NaN     NaN     NaN
# min         ...              NaN     NaN     NaN     NaN     NaN
# 25%         ...              NaN     NaN     NaN     NaN     NaN
# 50%         ...              NaN     NaN     NaN     NaN     NaN
# 75%         ...              NaN     NaN     NaN     NaN     NaN
# max         ...              NaN     NaN     NaN     NaN     NaN
#
#                Var228  Var229  Var230    Conversion            ID
# count           40053   17314     0.0  40053.000000  40053.000000
# unique             29       4     NaN           NaN           NaN
# top     F2FyR07IdsN7I    am7c     NaN           NaN           NaN
# freq            26189    9369     NaN           NaN           NaN
# mean              NaN     NaN     NaN     -0.852795  20027.000000
# std               NaN     NaN     NaN      0.522252  11562.449503
# min               NaN     NaN     NaN     -1.000000      1.000000
# 25%               NaN     NaN     NaN     -1.000000  10014.000000
# 50%               NaN     NaN     NaN     -1.000000  20027.000000
# 75%               NaN     NaN     NaN     -1.000000  30040.000000
# max               NaN     NaN     NaN      1.000000  40053.000000
#
# [11 rows x 232 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40053 entries, 0 to 40052
# Columns: 232 entries, Var1 to ID
# dtypes: float64(191), int64(3), object(38)
# memory usage: 70.9+ MB

# %%
data.dtypes
# Out:
# Var1          float64
# Var2          float64
# Var3          float64
# Var4          float64
# Var5          float64
# Var6          float64
# Var7          float64
# Var8          float64
# Var9          float64
# Var10         float64
# Var11         float64
# Var12         float64
# Var13         float64
# Var14         float64
# Var15         float64
# Var16         float64
# Var17         float64
# Var18         float64
# Var19         float64
# Var20         float64
# Var21         float64
# Var22         float64
# Var23         float64
# Var24         float64
# Var25         float64
# Var26         float64
# Var27         float64
# Var28         float64
# Var29         float64
# Var30         float64
#                ...
# Var203         object
# Var204         object
# Var205         object
# Var206         object
# Var207         object
# Var208         object
# Var209        float64
# Var210         object
# Var211         object
# Var212         object
# Var213         object
# Var214         object
# Var215         object
# Var216         object
# Var217         object
# Var218         object
# Var219         object
# Var220         object
# Var221         object
# Var222         object
# Var223         object
# Var224         object
# Var225         object
# Var226         object
# Var227         object
# Var228         object
# Var229         object
# Var230        float64
# Conversion      int64
# ID              int64
# Length: 232, dtype: object

# %% [markdown]
# La variable objetivo llamada "Conversion" es tipo numerica y debería ser tipo String, ya que es una variable binaria categorica.

# %%
data.Conversion=data.Conversion.astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40053 entries, 0 to 40052
# Columns: 232 entries, Var1 to ID
# dtypes: float64(191), int64(2), object(39)
# memory usage: 70.9+ MB

# %% [markdown]
# Podemos ver que la cantidad de columnas es de 232 y la cantidad de filas es de 40.053.

# %%
data.shape
# Out:
# (40053, 232)

# %% [markdown]
# Se va  definir que las columnas que contengan menos del 80% de sus valores van a ser eliminadas. Es decir que la cantidad de datos no nulos en la columna sea superior a 32.042

# %%
list_null_colums = data.isnull().sum()
list_null_colums
# Out:
# Var1          39504
# Var2          39066
# Var3          39067
# Var4          38811
# Var5          38847
# Var6           4412
# Var7           4404
# Var8          40053
# Var9          39504
# Var10         38847
# Var11         39067
# Var12         39610
# Var13          4404
# Var14         39067
# Var15         40053
# Var16         38847
# Var17         38811
# Var18         38811
# Var19         38811
# Var20         40053
# Var21          4412
# Var22          3984
# Var23         38847
# Var24          5774
# Var25          3984
# Var26         38847
# Var27         38847
# Var28          3986
# Var29         39504
# Var30         39504
#               ...
# Var203          120
# Var204            0
# Var205         1558
# Var206         4412
# Var207            0
# Var208          120
# Var209        40053
# Var210            0
# Var211            0
# Var212            0
# Var213        39144
# Var214        20340
# Var215        39511
# Var216            0
# Var217          558
# Var218          558
# Var219         4168
# Var220            0
# Var221            0
# Var222            0
# Var223         4168
# Var224        39402
# Var225        20932
# Var226            0
# Var227            0
# Var228            0
# Var229        22739
# Var230        40053
# Conversion        0
# ID                0
# Length: 232, dtype: int64

# %% [markdown]
# Ahora se va a proceder a borrar las columnas que no superen el umbral.

# %%
for x in range(len(data.columns)):
  if list_null_colums[x] >= 8011:
    data = data.drop([list_null_colums.keys()[x]],axis=1)

# %% [markdown]
# Vamos a ver con cuantas columnas nos quedamos

# %%
data.shape
# Out:
# (40053, 68)

# %% [markdown]
# Tenemos 68 columnas que tienen 80% de sus datos no nulos

# %%
data.head(20)
# Out:
#       Var6  Var7   Var13   Var21   Var22  Var24  Var25   Var28  Var35  \
# 0   1526.0   7.0   184.0   464.0   580.0   14.0  128.0  166.56    0.0
# 1    525.0   0.0     0.0   168.0   210.0    2.0   24.0  353.52    0.0
# 2   5236.0   7.0   904.0  1212.0  1515.0   26.0  816.0  220.08    0.0
# 3      NaN   0.0     0.0     NaN     0.0    NaN    0.0   22.08    0.0
# 4   1029.0   7.0  3216.0    64.0    80.0    4.0   64.0  200.00    0.0
# 5    658.0   7.0  3156.0   224.0   280.0    2.0   72.0  200.00    5.0
# 6     77.0   0.0     0.0    32.0    40.0    2.0   16.0  230.56    0.0
# 7   1176.0   7.0  2912.0   200.0   250.0    2.0   64.0  300.32    0.0
# 8   1141.0   7.0   164.0   208.0   260.0    2.0   72.0  166.56    5.0
# 9    490.0   7.0  2060.0    92.0   115.0    6.0  112.0  133.12    0.0
# 10   798.0  14.0  2892.0   236.0   295.0    8.0   40.0  133.12    5.0
# 11   595.0   0.0  2044.0     0.0     0.0    NaN    0.0  240.56    0.0
# 12  2268.0   0.0     0.0   480.0   600.0   10.0  216.0  176.56    0.0
# 13  3633.0   7.0   500.0   148.0   185.0    0.0    8.0  236.08    0.0
# 14   259.0   0.0   348.0     8.0    10.0    0.0    0.0  166.56    0.0
# 15  1449.0   7.0    28.0   168.0   210.0    2.0   32.0  166.56    5.0
# 16   574.0   7.0  1752.0    12.0    15.0    2.0    0.0  253.52    0.0
# 17   245.0   0.0     0.0   168.0   210.0    2.0   56.0  272.08    0.0
# 18    14.0   0.0     0.0    20.0    25.0    2.0    0.0   86.96    0.0
# 19   826.0   0.0    24.0   192.0   240.0    2.0   80.0  166.56    0.0
#
#         Var38 ...   Var219   Var220   Var221   Var222      Var223  Var226  \
# 0      3570.0 ...     FzaX  1YVfGrO     oslk  fXVEsaq  jySVZNlOJy    xb3V
# 1   4764966.0 ...     FzaX  0AJo2f2     oslk  2Kb5FSF  LM8l689qOp    fKCe
# 2   5883894.0 ...     FzaX  JFM1BiF  Al6ZaUT  NKv4yOc  jySVZNlOJy    Qu4f
# 3         0.0 ...     FzaX  L91KIiz     oslk  CE7uk3u  LM8l689qOp    FSa2
# 4         0.0 ...     FzaX  OrnLfvc     oslk  1J2cvxe  LM8l689qOp    FSa2
# 5         0.0 ...     FzaX  KbkKEj0     zCkv  QqVuch3  LM8l689qOp    Qcbd
# 6   3776496.0 ...      NaN  U8IKsQe     oslk  R2LdzOv         NaN    FSa2
# 7   6014460.0 ...     FzaX  ROeipLp     zCkv  K2SqEo9  jySVZNlOJy    PM2D
# 8   5317974.0 ...     FzaX  fabLnWA     oslk  EPqQcw6  LM8l689qOp    FSa2
# 9      3534.0 ...     FzaX  4UxGlow     zCkv  catzS2D  LM8l689qOp    WqMG
# 10   446868.0 ...     qxDb  OXxlI5k     oslk  VWtIBQt  LM8l689qOp    FSa2
# 11        0.0 ...     FzaX  fxJmel6     zCkv  WfsWw2A  LM8l689qOp    me1d
# 12    87294.0 ...     FzaX  WaovEWW     oslk  QKXEsaq  LM8l689qOp    Qu4f
# 13  8521620.0 ...     FzaX  Hlo8hdx     oslk  kYwEsaq  LM8l689qOp    PM2D
# 14        0.0 ...     FzaX  XsNOZ4E     oslk  IIvQguc  LM8l689qOp    Qu4f
# 15   548748.0 ...  AU8pNoi  4UxGlow  QKW8DRm  catzS2D  LM8l689qOp    WqMG
# 16        0.0 ...     qxDb  meWmFX7     oslk  DQ3iZDY  jySVZNlOJy    FSa2
# 17  4663572.0 ...     FzaX  6g5Ojel     oslk  UbjqFbB  LM8l689qOp    TNEC
# 18  7642260.0 ...      NaN  b0vOZ4E     oslk  1gu2qo0         NaN    FSa2
# 19        0.0 ...     FzaX  ALC68SY     oslk  9JvQQMs  LM8l689qOp    453m
#
#      Var227                  Var228  Conversion  ID
# 0      RAYp           F2FyR07IdsN7I          -1   1
# 1      RAYp           F2FyR07IdsN7I          -1   2
# 2   02N6s8f           ib5G6X1eUxUn6          -1   3
# 3      RAYp           F2FyR07IdsN7I          -1   4
# 4      RAYp           F2FyR07IdsN7I          -1   5
# 5   02N6s8f                 Zy3gnGM          -1   6
# 6      RAYp           F2FyR07IdsN7I          -1   7
# 7      6fzt  am14IcfM7tWLrUmRT52KtA          -1   8
# 8      RAYp                 55YFVY9          -1   9
# 9      ZI9m           ib5G6X1eUxUn6          -1  10
# 10     RAYp           F2FyR07IdsN7I          -1  11
# 11     ZI9m              iyHGyLCEkQ          -1  12
# 12     RAYp           F2FyR07IdsN7I          -1  13
# 13     RAYp           F2FyR07IdsN7I           1  14
# 14     RAYp                 55YFVY9          -1  15
# 15     ZI9m           ib5G6X1eUxUn6          -1  16
# 16     RAYp           F2FyR07IdsN7I          -1  17
# 17     RAYp           F2FyR07IdsN7I          -1  18
# 18     RAYp           F2FyR07IdsN7I          -1  19
# 19     RAYp           F2FyR07IdsN7I          -1  20
#
# [20 rows x 68 columns]

# %%
data.count()
# Out:
# Var6          35641
# Var7          35649
# Var13         35649
# Var21         35641
# Var22         36069
# Var24         34279
# Var25         36069
# Var28         36067
# Var35         36069
# Var38         36069
# Var44         36069
# Var57         40053
# Var65         35649
# Var73         40053
# Var74         35649
# Var76         36069
# Var78         36069
# Var81         35641
# Var83         36069
# Var85         36069
# Var109        34279
# Var112        36069
# Var113        40053
# Var119        35641
# Var123        36069
# Var125        35649
# Var132        36069
# Var133        36069
# Var134        36069
# Var140        35649
#               ...
# Var192        39765
# Var193        40053
# Var195        40053
# Var196        40053
# Var197        39933
# Var198        40053
# Var199        40050
# Var202        40053
# Var203        39933
# Var204        40053
# Var205        38495
# Var206        35641
# Var207        40053
# Var208        39933
# Var210        40053
# Var211        40053
# Var212        40053
# Var216        40053
# Var217        39495
# Var218        39495
# Var219        35885
# Var220        40053
# Var221        40053
# Var222        40053
# Var223        35885
# Var226        40053
# Var227        40053
# Var228        40053
# Conversion    40053
# ID            40053
# Length: 68, dtype: int64

# %% [markdown]
# Como se puede observar muchas de las variables no tienen la misma cantidad de datos, por lo tanto se analizará por filas, cuales son las que tienen la mitad o más de su información tipo null o vacía.

# %%
data.shape
# Out:
# (40053, 68)

# %%
data_aux = data.dropna()

# %%
data_aux.shape
# Out:
# (29410, 68)

# %%
list_null_rows=data.isnull().sum(axis=1) 
list_null_rows
# Out:
# 0         0
# 1         2
# 2         0
# 3         9
# 4         0
# 5         0
# 6         2
# 7         2
# 8         0
# 9         0
# 10        0
# 11        3
# 12        0
# 13        0
# 14        0
# 15        0
# 16        0
# 17        0
# 18        2
# 19        0
# 20        0
# 21        0
# 22        0
# 23        0
# 24        0
# 25        0
# 26        0
# 27        9
# 28        2
# 29        0
#          ..
# 40023     0
# 40024     0
# 40025    36
# 40026     0
# 40027     0
# 40028     0
# 40029     0
# 40030    38
# 40031     0
# 40032     0
# 40033     0
# 40034     0
# 40035     0
# 40036     6
# 40037     0
# 40038     0
# 40039     0
# 40040     6
# 40041     1
# 40042     3
# 40043     8
# 40044     0
# 40045     0
# 40046     0
# 40047     0
# 40048     0
# 40049     0
# 40050     0
# 40051    36
# 40052     0
# Length: 40053, dtype: int64

# %%
for x in range(len(data.ID)):
  if list_null_rows[x] >= 34:
    print(list_null_rows[x])
# Out:
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 37
# 38
# 38
# 37
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 38
# 37
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 39
# 36
# 38
# 40
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 39
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 39
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 38
# 38
# 39
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 39
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 40
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 39
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 37
# 38
# 36
# 38
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 38
# 36
# 38
# 38
# 38
# 39
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 39
# 36
# 36
# 38
# 37
# 39
# 36
# 36
# 38
# 36
# 37
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 37
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 39
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 39
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 37
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 39
# 36
# 36
# 39
# 38
# 39
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 37
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 37
# 38
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 39
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 39
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 38
# 38
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 41
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 36
# 38
# 38
# 36
# 37
# 36
# 39
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 37
# 36
# 36
# 36
# 36
# 38
# 40
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 39
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 38
# 36
# 38
# 39
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 37
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 38
# 36
# 36
# 36
# 36
# 39
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 39
# 38
# 38
# 36
# 37
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 38
# 36
# 39
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 37
# 38
# 36
# 37
# 38
# 40
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 38
# 37
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 38
# 38
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 39
# 39
# 38
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 39
# 36
# 38
# 36
# 36
# 38
# 36
# 37
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 37
# 37
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 39
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 38
# 38
# 38
# 37
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 38
# 38
# 36
# 37
# 38
# 36
# 38
# 37
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 39
# 36
# 37
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 37
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 39
# 38
# 36
# 38
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 40
# 36
# 38
# 36
# 37
# 38
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 39
# 38
# 36
# 37
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 37
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 40
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 40
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 40
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 38
# 36
# 36
# 40
# 38
# 36
# 37
# 36
# 39
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 39
# 39
# 38
# 38
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 36
# 38
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 39
# 38
# 38
# 36
# 38
# 42
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 38
# 38
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 38
# 37
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 41
# 36
# 36
# 36
# 37
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 37
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 37
# 38
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 37
# 38
# 36
# 38
# 37
# 39
# 36
# 39
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 37
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 38
# 38
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 38
# 37
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 39
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 38
# 38
# 36
# 36
# 36
# 38
# 37
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 37
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 37
# 38
# 38
# 39
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 40
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 37
# 39
# 36
# 36
# 36
# 37
# 37
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 39
# 38
# 39
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 37
# 38
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 39
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 37
# 37
# 38
# 40
# 36
# 36
# 38
# 39
# 36
# 36
# 36
# 40
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 37
# 36
# 39
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 39
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 38
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 37
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 39
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 38
# 38
# 38
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 37
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 36
# 38
# 39
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 37
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 38
# 36
# 38
# 37
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 37
# 39
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 39
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 38
# 36
# 36
# 37
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 39
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 37
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 40
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 37
# 36
# 36
# 38
# 37
# 36
# 36
# 39
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 38
# 38
# 36
# 39
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 39
# 36
# 36
# 38
# 37
# 36
# 36
# 36
# 36
# 39
# 37
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 37
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 38
# 38
# 38
# 36
# 36
# 38
# 39
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 37
# 38
# 36
# 36
# 38
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 39
# 36
# 38
# 36
# 36
# 39
# 36
# 36
# 36
# 38
# 38
# 36
# 40
# 38
# 36
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 37
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 39
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 39
# 38
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 37
# 36
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 40
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 39
# 38
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 39
# 38
# 36
# 37
# 36
# 36
# 38
# 38
# 38
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 39
# 36
# 37
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 38
# 38
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 37
# 38
# 36
# 36
# 38
# 38
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 37
# 38
# 36
# 36
# 36
# 36
# 37
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 36
# 38
# 36
# 36
# 36
# 36
# 38
# 36
# 38
# 38
# 36
# 36
# 38
# 36

# %%
for x in range(len(data.ID)):
  if list_null_rows[x] >= 34:
    data = data.drop([list_null_rows.keys()[x]],axis=0)

# %%
data.shape
# Out:
# (36069, 68)

# %%
data.count()
# Out:
# Var6          35641
# Var7          35649
# Var13         35649
# Var21         35641
# Var22         36069
# Var24         34279
# Var25         36069
# Var28         36067
# Var35         36069
# Var38         36069
# Var44         36069
# Var57         36069
# Var65         35649
# Var73         36069
# Var74         35649
# Var76         36069
# Var78         36069
# Var81         35641
# Var83         36069
# Var85         36069
# Var109        34279
# Var112        36069
# Var113        36069
# Var119        35641
# Var123        36069
# Var125        35649
# Var132        36069
# Var133        36069
# Var134        36069
# Var140        35649
#               ...
# Var192        35825
# Var193        36069
# Var195        36069
# Var196        36069
# Var197        35955
# Var198        36069
# Var199        36066
# Var202        36069
# Var203        35955
# Var204        36069
# Var205        34697
# Var206        35641
# Var207        36069
# Var208        35955
# Var210        36069
# Var211        36069
# Var212        36069
# Var216        36069
# Var217        35556
# Var218        35556
# Var219        32972
# Var220        36069
# Var221        36069
# Var222        36069
# Var223        32972
# Var226        36069
# Var227        36069
# Var228        36069
# Conversion    36069
# ID            36069
# Length: 68, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36069 entries, 0 to 40052
# Data columns (total 68 columns):
# Var6          35641 non-null float64
# Var7          35649 non-null float64
# Var13         35649 non-null float64
# Var21         35641 non-null float64
# Var22         36069 non-null float64
# Var24         34279 non-null float64
# Var25         36069 non-null float64
# Var28         36067 non-null float64
# Var35         36069 non-null float64
# Var38         36069 non-null float64
# Var44         36069 non-null float64
# Var57         36069 non-null float64
# Var65         35649 non-null float64
# Var73         36069 non-null int64
# Var74         35649 non-null float64
# Var76         36069 non-null float64
# Var78         36069 non-null float64
# Var81         35641 non-null float64
# Var83         36069 non-null float64
# Var85         36069 non-null float64
# Var109        34279 non-null float64
# Var112        36069 non-null float64
# Var113        36069 non-null float64
# Var119        35641 non-null float64
# Var123        36069 non-null float64
# Var125        35649 non-null float64
# Var132        36069 non-null float64
# Var133        36069 non-null float64
# Var134        36069 non-null float64
# Var140        35649 non-null float64
# Var143        36069 non-null float64
# Var144        35641 non-null float64
# Var149        34279 non-null float64
# Var153        36069 non-null float64
# Var160        36069 non-null float64
# Var163        36069 non-null float64
# Var173        36069 non-null float64
# Var181        36069 non-null float64
# Var192        35825 non-null object
# Var193        36069 non-null object
# Var195        36069 non-null object
# Var196        36069 non-null object
# Var197        35955 non-null object
# Var198        36069 non-null object
# Var199        36066 non-null object
# Var202        36069 non-null object
# Var203        35955 non-null object
# Var204        36069 non-null object
# Var205        34697 non-null object
# Var206        35641 non-null object
# Var207        36069 non-null object
# Var208        35955 non-null object
# Var210        36069 non-null object
# Var211        36069 non-null object
# Var212        36069 non-null object
# Var216        36069 non-null object
# Var217        35556 non-null object
# Var218        35556 non-null object
# Var219        32972 non-null object
# Var220        36069 non-null object
# Var221        36069 non-null object
# Var222        36069 non-null object
# Var223        32972 non-null object
# Var226        36069 non-null object
# Var227        36069 non-null object
# Var228        36069 non-null object
# Conversion    36069 non-null object
# ID            36069 non-null int64
# dtypes: float64(37), int64(2), object(29)
# memory usage: 19.0+ MB

# %%
data.describe(include="all")
# Out:
#                  Var6          Var7          Var13         Var21  \
# count    35641.000000  35649.000000   35649.000000  35641.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean      1322.620157      6.803052    1243.547477    235.027188
# std       2620.594097      6.337622    2789.894728    569.993340
# min          0.000000      0.000000       0.000000      0.000000
# 25%        518.000000      0.000000       0.000000    112.000000
# 50%        861.000000      7.000000     228.000000    144.000000
# 75%       1428.000000      7.000000    1600.000000    228.000000
# max     114079.000000    140.000000  197872.000000  36272.000000
#
#                Var22         Var24         Var25         Var28         Var35  \
# count   36069.000000  34279.000000  36069.000000  36067.000000  36069.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean      290.822174      4.499781     96.971250    224.476595      0.726247
# std       710.141392      9.846298    218.407522     99.457181      3.039886
# min         0.000000      0.000000      0.000000    -66.880000      0.000000
# 25%       135.000000      0.000000     16.000000    166.560000      0.000000
# 50%       180.000000      2.000000     48.000000    220.080000      0.000000
# 75%       285.000000      6.000000    112.000000    266.400000      0.000000
# max     45340.000000    488.000000  13168.000000   5158.560000    110.000000
#
#                Var38     ...       Var219   Var220  Var221   Var222  \
# count   3.606900e+04     ...        32972    36069   36069    36069
# unique           NaN     ...           22     3619       7     3619
# top              NaN     ...         FzaX  4UxGlow    oslk  catzS2D
# freq             NaN     ...        29612     3574   26352     3574
# mean    2.579645e+06     ...          NaN      NaN     NaN      NaN
# std     3.008783e+06     ...          NaN      NaN     NaN      NaN
# min     0.000000e+00     ...          NaN      NaN     NaN      NaN
# 25%     8.034000e+03     ...          NaN      NaN     NaN      NaN
# 50%     1.299918e+06     ...          NaN      NaN     NaN      NaN
# 75%     4.565718e+06     ...          NaN      NaN     NaN      NaN
# max     1.884690e+07     ...          NaN      NaN     NaN      NaN
#
#             Var223  Var226  Var227         Var228  Conversion           ID
# count        32972   36069   36069          36069       36069  36069.00000
# unique           4      23       7             29           2          NaN
# top     LM8l689qOp    FSa2    RAYp  F2FyR07IdsN7I          -1          NaN
# freq         26401    5825   24980          22480       33259          NaN
# mean           NaN     NaN     NaN            NaN         NaN  20019.36993
# std            NaN     NaN     NaN            NaN         NaN  11555.98475
# min            NaN     NaN     NaN            NaN         NaN      1.00000
# 25%            NaN     NaN     NaN            NaN         NaN  10016.00000
# 50%            NaN     NaN     NaN            NaN         NaN  20000.00000
# 75%            NaN     NaN     NaN            NaN         NaN  30035.00000
# max            NaN     NaN     NaN            NaN         NaN  40053.00000
#
# [11 rows x 68 columns]

# %% [markdown]
# Como algunas variables  presentan un porcentaje pequeño de datos vacíos (aprox. entre el 1% al 14% de sus datos son nulos) el cual no afectará a la variable objetivo, se considera que la mejor solución es la siguiente:
# 1. Para las variables numéricas reemplazar dichos datos nulos por el promedio de los valores presentes en la respectiva variable.
#
# 2. Para las variables categoricas o tipo object reemplazar los datos nulos por el dato que más porcentaje de aparición tiene.

# %%
#var=data[data.columns[0]].dtype
#palabra_comun=data[data.columns[64]].value_counts()
#data1=data
# df1['weight'] = surveys_df['weight'].fillna(surveys_df['weight'].mean())


#data1=data
#promedio=data1["Var193"].value_counts().idxmax()
#data1["Var193"]=data1["Var193"].fillna(promedio)
#otro=data1["Var193"].isnull().sum()
#data1.head(5)
#prom=promedio
#print(len(data["Var223"]),"valores nulos",otro,"este es promedio",prom)

# %%
data=data.drop_duplicates(keep="first")
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Var6, Var7, Var13, Var21, Var22, Var24, Var25, Var28, Var35, Var38, Var44, Var57, Var65, Var73, Var74, Var76, Var78, Var81, Var83, Var85, Var109, Var112, Var113, Var119, Var123, Var125, Var132, Var133, Var134, Var140, Var143, Var144, Var149, Var153, Var160, Var163, Var173, Var181, Var192, Var193, Var195, Var196, Var197, Var198, Var199, Var202, Var203, Var204, Var205, Var206, Var207, Var208, Var210, Var211, Var212, Var216, Var217, Var218, Var219, Var220, Var221, Var222, Var223, Var226, Var227, Var228, Conversion, ID]
# Index: []
#
# [0 rows x 68 columns]

# %%
data.shape
# Out:
# (36069, 68)

# %%
for x in range(len(data.columns)):
  var=data[data.columns[x]].dtype
 
  if(var=="float64" or var=="int64"):
   
    promedio=data[data.columns[x]].mean()
    data[data.columns[x]]=data[data.columns[x]].fillna(promedio)
   # print("1")
 
  elif(var=="object"):
    
    palabra_comun=data[data.columns[x]].value_counts().idxmax()
    data[data.columns[x]]=data[data.columns[x]].fillna(palabra_comun)
    #print("2")
data.count()
# Out:
# Var6          36069
# Var7          36069
# Var13         36069
# Var21         36069
# Var22         36069
# Var24         36069
# Var25         36069
# Var28         36069
# Var35         36069
# Var38         36069
# Var44         36069
# Var57         36069
# Var65         36069
# Var73         36069
# Var74         36069
# Var76         36069
# Var78         36069
# Var81         36069
# Var83         36069
# Var85         36069
# Var109        36069
# Var112        36069
# Var113        36069
# Var119        36069
# Var123        36069
# Var125        36069
# Var132        36069
# Var133        36069
# Var134        36069
# Var140        36069
#               ...
# Var192        36069
# Var193        36069
# Var195        36069
# Var196        36069
# Var197        36069
# Var198        36069
# Var199        36069
# Var202        36069
# Var203        36069
# Var204        36069
# Var205        36069
# Var206        36069
# Var207        36069
# Var208        36069
# Var210        36069
# Var211        36069
# Var212        36069
# Var216        36069
# Var217        36069
# Var218        36069
# Var219        36069
# Var220        36069
# Var221        36069
# Var222        36069
# Var223        36069
# Var226        36069
# Var227        36069
# Var228        36069
# Conversion    36069
# ID            36069
# Length: 68, dtype: int64

# %% [markdown]
# Todas las variables sin espacios o campos vacíos.

# %% [markdown]
# Se borra la columna id debido a que no es necesaria para lo que sigue del proyecto

# %%
data = data.drop(["ID"], axis=1)

# %% [markdown]
# **Visualización de los datos**

# %% [markdown]
# Para esto es necesario separar variables categoricas de las numericas.

# %%
len(data.values[0])
# Out:
# 67

# %%
var_indep_cat = []
var_indep_num = []

for x in range(len(data.columns)):
  var=data[data.columns[x]].dtype
  if var=="float64" or var=="int64":
    var_indep_num.append(data.columns[x])
  elif var == "object":
    var_indep_cat.append(data.columns[x])
    
var_indep_cat.remove('Conversion')

# %%
var_aux = var_indep_cat[0:1]
fig = plt.figure(figsize=(18,15))
i=1
for var_cat in var_aux:
    ax = fig.add_subplot(math.ceil(len(var_indep_cat)/2), 2, i)
    sns.countplot(x=var_cat, hue="Conversion", data=data)
    plt.title(var_cat)
    plt.legend(['1', '-1'])
    i+=1

# %%
var_indep_num_aux = ['Var28', 'Var113', 'Var13', 'Var134', 'Var119', 'Var38', 'Var25']

plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
#otra variable a tener presente var7,var38 var73, var76, var81, var132, var134, var153
#Falta mirar con variables object
sns.boxplot(x="Conversion", y=data.Var28, data=data)
plt.subplot(1,2,2)
sns.boxplot(x="Conversion", y=data.Var13, data=data)

# %% [markdown]
# voy a revisar si alguna categorica tiene una cantidad de clases menor a 5

# %%
data.Var195.unique()
# Out:
# array(['taul', 'LfvqpCtLOY', 'ev6I', 'CiJDdr4TQ0rGERIS', 'ArtjQZmIvr94p',
#        'CuXi4je', 'I9xt3GBDKUbd8', 'hiMqnEM7VgIk4JUu', 'b_3Q',
#        'ArtjQZ8ftr3NB', 'I9xt3GMcxUnBZ', 'bsZtYxFjzA', 'I9xt3GDRhUK7p',
#        'lSbpiq1', 'ZZBPiZh', 'ArtjQZQO1r9fC', 'TnJpfvsJgF', 'XMIgoIlPqx',
#        'BNjsq81k1tWAYigY', 'I9xt3Gi01UK7p', 'CiJsoa4TQ0rGHlMp',
#        'V10_0kx3ZF2we', 'F1JQrEL'], dtype=object)

# %% [markdown]
# aplico un arbol al modelo para ver mejores columnas

# %% [markdown]
# # Clasificación a partir un árbol de decisión

# %% [markdown]
# Los árboles de decisión permiten utilizar tanto las variables predictivas categóricas como las numéricas.
# No todas las variables van a ser útiles. El árbol se va a encargar de encontrar la mejor variable a utilizar en el contexto del subconjunto de datos de cada rama.
#
# Veamos cómo se crea un árbol de decisión en scikit-learn, y algunos de los parámetros más importantes:

# %%
np.random.seed(1234)
ctree = tree.DecisionTreeClassifier(
    criterion='entropy', # el criterio de particionamiento de un conjunto de datos (gini, entropy)
    max_depth=7,      # prepoda: controla la profundidad del árbol (largo máximo de las ramas)
    min_samples_split=1000, # prepoda: el mínimo número de registros necesarios para crear una nueva rama
    min_samples_leaf=1,  # prepoda: el mínimo número de registros en una hoja
    random_state=None,   # semilla del generador aleatorio utilizado para 
    max_leaf_nodes=None, # prepoda: máximo número de nodos hojas
    min_impurity_decrease=0.0, # prepoda: umbral mínimo de reducción de la impureza para aceptar la creación de una rama
    class_weight=None    # permite asociar pesos a las clases, en el caso de diferencias de importancia entre ellas
)

# %% [markdown]
# **Nota editorial**: no puedo creer que scikit-learn soporte en sus árboles de decisión solamente variables independientes numéricas!!!!! Toca entonces utilizar un encoding (one hot).

# %%
#data_cat_one_hot = pd.get_dummies(data[var_indep_cat], prefix=var_indep_cat)
#X = data[var_indep_num].join(data_cat_one_hot)
X = data[var_indep_num]
y = data['Conversion']
X.shape
# Out:
# (36069, 38)

# %% [markdown]
# Quedaron 24 variables independientes.

# %% [markdown]
# Vamos a normalizar las dos variables numéricas para que tengan la misma importancia en el modelo de KNN, dado que este se basa en la distancia las diferencias de escalas son importantes.

# %%
np.random.seed(1234)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify=y)

# %%
# Crear un normalizador Min-Max
min_max_scaler = preprocessing.MinMaxScaler()

# Aprender sus parámetros con el set de entrenamiento y transformar los dos datasets
X_train_scaled = min_max_scaler.fit_transform(X_train)
X_test_scaled = min_max_scaler.transform(X_test)

# %%
y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# %%
ctree.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=7,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=1000,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# Una vez el árbol es aprendido, se puede consultar diferentes atributos.
# El mas interesante, aparte del árbol en sí, es el que asocia un índice de importancia a los atributos independientes en la clasificación:

# %%
ctree.feature_importances_
# Out:
# array([0.01676525, 0.        , 0.01420165, 0.        , 0.        ,
#        0.        , 0.02454721, 0.69434607, 0.        , 0.03076348,
#        0.        , 0.00743537, 0.00717249, 0.01092159, 0.        ,
#        0.        , 0.        , 0.03057569, 0.01605986, 0.        ,
#        0.        , 0.        , 0.11395293, 0.        , 0.01060553,
#        0.        , 0.        , 0.        , 0.        , 0.0083125 ,
#        0.        , 0.        , 0.        , 0.01434039, 0.        ,
#        0.        , 0.        , 0.        ])

# %%
X.columns
# Out:
# Index(['Var6', 'Var7', 'Var13', 'Var21', 'Var22', 'Var24', 'Var25', 'Var28',
#        'Var35', 'Var38', 'Var44', 'Var57', 'Var65', 'Var73', 'Var74', 'Var76',
#        'Var78', 'Var81', 'Var83', 'Var85', 'Var109', 'Var112', 'Var113',
#        'Var119', 'Var123', 'Var125', 'Var132', 'Var133', 'Var134', 'Var140',
#        'Var143', 'Var144', 'Var149', 'Var153', 'Var160', 'Var163', 'Var173',
#        'Var181'],
#       dtype='object')

# %% [markdown]
# Encontramos entonces que las variables en orden de importancia son:

# %%
X.columns[np.argsort(-ctree.feature_importances_)]
# Out:
# Index(['Var28', 'Var113', 'Var38', 'Var81', 'Var25', 'Var6', 'Var83', 'Var153',
#        'Var13', 'Var73', 'Var123', 'Var140', 'Var57', 'Var65', 'Var132',
#        'Var133', 'Var134', 'Var22', 'Var125', 'Var149', 'Var160', 'Var163',
#        'Var143', 'Var144', 'Var7', 'Var24', 'Var112', 'Var109', 'Var85',
#        'Var173', 'Var78', 'Var76', 'Var74', 'Var44', 'Var21', 'Var35',
#        'Var119', 'Var181'],
#       dtype='object')

# %% [markdown]
# ## Evaluación del modelo

# %% [markdown]
# Ya tenemos el modelo "aprendido" con el dataset de 20000 instancias.
# Vamos ahora a evaluarlo sobre ese mismo dataset para poder ver los éxitos y errores de la predicción.

# %%
y_pred = ctree.predict(X_test_scaled)

# %%
cm= metrics.confusion_matrix(y_test, y_pred)
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title("Matriz de confusión para K=5")
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, y_test.unique())
plt.yticks(tick_marks, y_test.unique())
plt.show()

# %%
print(cm)
print("Exactitud: ", metrics.accuracy_score(y_test, y_pred))
print("Kappa    : ", metrics.cohen_kappa_score(y_test, y_pred))
print("Precisión     : ", metrics.precision_score(y_test, y_pred, "LEAVE", average='macro'))
print("Recall        : ", metrics.recall_score(y_test, y_pred, "LEAVE", average='macro'))
VN = np.sum(cm[1:3,1:3])
FP = np.sum(cm[0,1:3])
specificity = VN/(VN+FP)
print("Especificidad : ", specificity)
print("F1-score      : ", metrics.f1_score(y_test, y_pred, "LEAVE", average='macro'))
# Out:
# [[9975    3]
#  [ 843    0]]
# Exactitud:  0.9218186858885501
# Kappa    :  -0.0005528166104669108
# Precisión     :  0.3073581068589388
# Recall        :  0.3332331128482662
# Especificidad :  0.0
# F1-score      :  0.3197730332756299
# C:\Users\jeher\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\jeher\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\jeher\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\jeher\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# Con el árbol completo, obtuvimos un nivel de accuracy del 61.68%, cuando el baseline era de 50.74%.

# %% [markdown]
# ## Overfitting: poda del árbol

# %% [markdown]
# Vamos a ver que hubiera pasado si limitamos el crecimiento del árbol (prepoda), controlando la profundidad del árbol y el mínimo número de registros de un nodo para permitir el particionamiento.

# %% [markdown]
# **Parte 3**:
#
# Modifiquen el parámetro **criterion** y los parámetros de pre-poda buscando una mejor exactitud del modelo:
# - **max_depth**: entre mas grande el valor, el árbol será más complejo (más número de niveles de profundidad)
# - **min_samples_split**: entre mas grande el valor, el árbol será más sencillo (se necesita tener más registros en un nodo para poder particionarlo)
# - **min_samples_leaf**: entre mas grande el valor, el árbol será más sencillo (se necesita tener más registros en una hoja para poder aceptarla, si no se llega a esa cardinalidad, no se permite el partionamiento de su nodo padre)
# - **min_impurity_decrease**: entre mas grande el valor, el árbol será más sencillo (un nivel de impureza bajo inferior a este umbral no desatará un particionamiento.

# %%
np.random.seed(1234)
ctree = tree.DecisionTreeClassifier(
    criterion='entropy', # el criterio de particionamiento de un conjunto de datos
    max_depth=10,      # prepoda: controla la profundidad del árbol (largo máximo de las ramas)
    min_samples_split=1000, # prepoda: el mínimo número de registros necesarios para crear una nueva rama
    min_samples_leaf=1,  # prepoda: el mínimo número de registros en una hoja
    random_state=None,   # semilla del generador aleatorio utilizado para 
    max_leaf_nodes=None, # prepoda: máximo número de nodos hojas
    min_impurity_decrease=0.0, # prepoda: umbral mínimo de reducción de la impureza para aceptar la creación de una rama
    class_weight=None    # permite asociar pesos a las clases, en el caso de diferencias de importancia entre ellas
)
ctree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=1000,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = ctree.predict(X_test)
print("Exactitud: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Exactitud:  0.9218186858885501

# %% [markdown]
# Podemos intentar con otro tipo de modelos, e.g KNN.

# %%
from sklearn.neighbors import KNeighborsClassifier
np.random.seed(1234)
knn = KNeighborsClassifier(n_neighbors=300)
knn.fit(X_train_scaled, y_train)
y_pred = knn.predict(X_test_scaled)
cm= metrics.confusion_matrix(y_test, y_pred)
print("Exactitud: ", metrics.accuracy_score(y_test, y_pred))
print("Kappa    : ", metrics.cohen_kappa_score(y_test, y_pred))
# Out:
# Exactitud:  0.9220959245910729
# Kappa    :  0.0

# %% [markdown]
# También con un modelo Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
np.random.seed(1234)
nb = GaussianNB()
nb.fit(X_train_scaled, y_train)
y_pred = nb.predict(X_test_scaled)
cm= metrics.confusion_matrix(y_test, y_pred)
print("Exactitud: ", metrics.accuracy_score(y_test, y_pred))
print("Kappa    : ", metrics.cohen_kappa_score(y_test, y_pred))
# Out:
# Exactitud:  0.325385823861011
# Kappa    :  0.02439922657690774

# %% [markdown]
# **Dataset de prueba para los modelos**-

# %%
for i in range(20025):
  dataset_prueba=data.iloc[i]
dataset_prueba
# Out:
# Var6                      1274
# Var7                         7
# Var13                      344
# Var21                      188
# Var22                      235
# Var24                        2
# Var25                       80
# Var28                   266.72
# Var35                       10
# Var38              2.08545e+06
# Var44                        0
# Var57                  1.21363
# Var65                       18
# Var73                      112
# Var74                        7
# Var76                        0
# Var78                        0
# Var81                  28127.3
# Var83                       40
# Var85                        8
# Var109                      48
# Var112                       0
# Var113                  307936
# Var119                     575
# Var123                      30
# Var125                     396
# Var132                      16
# Var133             4.03307e+06
# Var134                  954772
# Var140                      30
#                     ...
# Var181                       0
# Var192              tr0rEyXktW
# Var193                 2Knk1KF
# Var195                    taul
# Var196                    1K8T
# Var197                    Wmd1
# Var198                 LG0JHBC
# Var199        1e6A3itvlKVGj2Xa
# Var202                    DFE6
# Var203                    9_Y1
# Var204                    SkZj
# Var205                 sJzTlal
# Var206                    haYg
# Var207              me75fM6ugJ
# Var208                    kIsH
# Var210                    uKAI
# Var211                    L84s
# Var212           XfqtO3UdzaXh_
# Var216                 XTbPUYD
# Var217                    PAqM
# Var218                    UYBR
# Var219                    FzaX
# Var220                 ZDjvbB7
# Var221                    oslk
# Var222                 nx1K0JH
# Var223              LM8l689qOp
# Var226                    Aoh3
# Var227                    RAYp
# Var228                 55YFVY9
# Conversion                  -1
# Name: 20027, Length: 67, dtype: object

# %% [markdown]
# Tener encuenta:
# * x= variable objetivo
# * y= variables que pueden influir en la variable x

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
# 378     8.000000   200.00000  166.560000   0.000000  0.000000e+00     ...
# 382    10.000000   208.00000  166.560000   0.000000  6.095400e+04     ...
# 397     0.000000     8.00000  133.120000   0.000000  0.000000e+00     ...
# 406    16.000000   112.00000  187.280000   0.000000  1.017180e+05     ...
# ...          ...         ...         ...        ...           ...     ...
# 39716   4.000000    48.00000  220.080000  10.000000  9.104280e+06     ...
# 39729  14.000000   560.00000  214.480000   0.000000  7.771800e+05     ...
# 39731  28.000000   456.00000  220.080000   5.000000  5.289594e+06     ...
# 39745   4.499781    96.97125  224.476595   0.726247  2.579645e+06     ...
# 39752   0.000000    64.00000  200.000000   0.000000  2.048400e+05     ...
# 39770   4.000000   136.00000  189.920000   0.000000  0.000000e+00     ...
# 39781   0.000000    48.00000  186.640000   5.000000  4.869906e+06     ...
# 39783   4.000000     8.00000  278.080000   0.000000  0.000000e+00     ...
# 39794   2.000000    72.00000  230.080000   0.000000  2.075064e+06     ...
# 39807   2.000000    88.00000  200.000000   0.000000  0.000000e+00     ...
# 39834   6.000000   280.00000  133.120000   0.000000  0.000000e+00     ...
# 39892   6.000000    40.00000  253.520000   0.000000  3.856110e+06     ...
# 39898   4.000000   128.00000  200.640000   0.000000  5.862000e+04     ...
# 39910   2.000000   112.00000  166.560000   0.000000  4.733460e+05     ...
# 39934   0.000000     0.00000  186.640000   5.000000  7.375500e+06     ...
# 39936  14.000000   280.00000  166.560000   0.000000  8.760000e+02     ...
# 39947   4.000000   184.00000  220.080000   0.000000  4.473426e+06     ...
# 39950   0.000000    40.00000  253.520000   0.000000  9.491040e+06     ...
# 39951   4.000000    96.00000  183.280000   0.000000  1.188768e+06     ...
# 39958   8.000000   136.00000  166.560000  10.000000  1.084260e+05     ...
# 39970   2.000000    56.00000  220.080000   0.000000  2.126442e+06     ...
# 39973  10.000000   216.00000  335.520000   0.000000  1.400400e+04     ...
# 39998   0.000000     0.00000  100.320000   0.000000  0.000000e+00     ...
# 40001   2.000000    32.00000  220.080000   0.000000  9.546480e+06     ...
# 40014   6.000000   128.00000  166.560000   0.000000  0.000000e+00     ...
# 40016   4.000000   232.00000  166.560000   0.000000  0.000000e+00     ...
# 40024   0.000000    16.00000  200.000000   0.000000  0.000000e+00     ...
# 40034   4.000000    96.00000  167.200000   0.000000  2.129520e+05     ...
# 40040   0.000000   144.00000  198.880000   0.000000  4.494924e+06     ...
# 40052   0.000000    48.00000  220.080000   5.000000  2.691228e+06     ...
#
#        Var218   Var219   Var220   Var221   Var222      Var223  Var226  \
# 13       cJvF     FzaX  Hlo8hdx     oslk  kYwEsaq  LM8l689qOp    PM2D
# 20       cJvF     FzaX  Qkc66eq  d0EEeJi  CmhRjAG  LM8l689qOp    fKCe
# 24       UYBR     FzaX  pqU6hzI     oslk  XKaTy9x        M_8D    Qcbd
# 58       cJvF     FzaX  4UxGlow     oslk  catzS2D  LM8l689qOp    7P5s
# 93       cJvF     FzaX  bDIfGrO     oslk  s4wQZmh  LM8l689qOp    Qcbd
# 98       UYBR     FzaX  4UxGlow     oslk  catzS2D  LM8l689qOp
FzaX  4UxGlow     oslk  catzS2D  LM8l689qOp    453m
# 39807    cJvF     qxDb  R8kKx11     zCkv  X9a41Yn  LM8l689qOp    szEZ
# 39834    UYBR     FzaX  R4hm94s     oslk  oSyMpgG  jySVZNlOJy    FSa2
# 39892    cJvF     FzaX  9Z93Kho     oslk  SJXzlpr  LM8l689qOp    Qu4f
# 39898    UYBR     FzaX  iEX0Q3K     oslk  LPD2Oqu  LM8l689qOp    453m
# 39910    cJvF     FzaX  jbWVmVv  Al6ZaUT  5mSp1PS  LM8l689qOp    7P5s
# 39934    UYBR     FzaX  hFp4fIi  d0EEeJi  t3TPLOe  LM8l689qOp    WqMG
# 39936    cJvF     FzaX  bDfRoKG     oslk  LUywS9i  LM8l689qOp    WqMG
# 39947    cJvF     FzaX  Tvpip6Z     zCkv  hHJsvbM  jySVZNlOJy    5Acm
# 39950    UYBR     FzaX  UISY_02     oslk  DGsqhZX  LM8l689qOp    FSa2
# 39951    UYBR     FzaX  R4hmHfO     oslk  9HlNxGX  LM8l689qOp    WqMG
# 39958    UYBR     FzaX  Phzi_Q3     z4pH  CxDRUH6  LM8l689qOp    FSa2
# 39970    cJvF     FzaX  KbkKEj0  Al6ZaUT  QqVuch3  jySVZNlOJy    FSa2
# 39973    cJvF  AU8pNoi  CnFYH7D     oslk  sQrQv5o  LM8l689qOp    xb3V
# 39998    UYBR     OFWH  rPpfql_     oslk  d1cRkup  LM8l689qOp    Qcbd
# 40001    cJvF     FzaX  4UxGlow  QKW8DRm  catzS2D  jySVZNlOJy    Aoh3
# 40014    UYBR     FzaX  WZA8iqZ     oslk  jCiQv5o  LM8l689qOp    kwS7
# 40016    UYBR     FzaX  aMa88FJ     oslk  tM4OEra  LM8l689qOp    PM2D
# 40024    cJvF     FzaX  EpcfrxM     oslk  ynwED8N  LM8l689qOp    szEZ
# 40034    cJvF     FzaX  B0LABPr     oslk  UP3EVaf  LM8l689qOp    Qu4f
# 40040    UYBR     FzaX  8_rYWu3     oslk  rT1Esaq  LM8l689qOp    xb3V
# 40052    cJvF     FzaX  ot6oLzk     oslk  IIvC99a  LM8l689qOp    xb3V
#
#         Var227                  Var228  Conversion
# 13        RAYp           F2FyR07IdsN7I           1
# 20     nIGXDli           F2FyR07IdsN7I           1
# 24        RAYp           F2FyR07IdsN7I           1
# 58        ZI9m              iyHGyLCEkQ           1
# 93        RAYp           F2FyR07IdsN7I           1
# 98        ZI9m                    VjDE           1
# 100       RAYp           F2FyR07IdsN7I           1
# 117    vJ_w8kB     WfJYmPMksSqa1pajvfG           1
# 128       RAYp           F2FyR07IdsN7I           1
# 149       RAYp           F2FyR07IdsN7I           1
# 205       RAYp           F2FyR07IdsN7I           1
# 206       RAYp           F2FyR07IdsN7I           1
# 207       RAYp           F2FyR07IdsN7I           1
# 238       RAYp           F2FyR07IdsN7I           1
# 254    vJ_w8kB     WfJ2BB2SFSqauljlfOB           1
# 259       RAYp           F2FyR07IdsN7I           1
# 281    nIGXDli        R4y5gQQWY8OodqDV           1
# 290       RAYp           F2FyR07IdsN7I           1
# 292       RAYp           F2FyR07IdsN7I           1
# 315       ZI9m        R4y5gQQWY8OodqDV           1
# 325       RAYp           F2FyR07IdsN7I           1
# 347    02N6s8f        R4y5gQQWY8OodqDV           1
# 354       RAYp           F2FyR07IdsN7I           1
# 359       ZI9m        R4y5gQQWY8OodqDV           1
# 362       RAYp           F2FyR07IdsN7I           1
# 374       ZI9m                    VjDE           1
# 378       RAYp           F2FyR07IdsN7I           1
# 382       RAYp           F2FyR07IdsN7I           1
# 397       RAYp           F2FyR07IdsN7I           1
# 406       ZI9m                    NoEd           1
# ...        ...                     ...         ...
# 39716     RAYp           F2FcTt7IdMT_v           1
# 39729     ZI9m                    NoEd           1
# 39731     RAYp           F2FyR07IdsN7I           1
# 39745     RAYp           F2FyR07IdsN7I           1
# 39752     RAYp           F2FyR07IdsN7I           1
# 39770     RAYp                 55YFVY9           1
# 39781  02N6s8f        R4y5gQQWY8OodqDV           1
# 39783     RAYp           F2FyR07IdsN7I           1
# 39794     ZI9m                    VjDE           1
# 39807     6fzt           xwM2aC7IdeMC0           1
# 39834     RAYp           F2FyR07IdsN7I           1
# 39892     RAYp           F2FyR07IdsN7I           1
# 39898     RAYp           F2FyR07IdsN7I           1
# 39910  02N6s8f           F2FyR07IdsN7I           1
# 39934  nIGXDli           F2FyR07IdsN7I           1
# 39936     RAYp           F2FyR07IdsN7I           1
# 39947     6fzt  SbOd7O8ky1wGNxp0Arj0Xs           1
# 39950     RAYp                 55YFVY9           1
# 39951     RAYp           F2FyR07IdsN7I           1
# 39958  02N6s8f           ib5G6X1eUxUn6           1
# 39970  02N6s8f           xwM2aC7IdeMC0           1
# 39973     RAYp           F2FyR07IdsN7I           1
# 39998     RAYp           F2FyR07IdsN7I           1
# 40001     ZI9m           ib5G6X1eUxUn6           1
# 40014     RAYp           F2FyR07IdsN7I           1
# 40016     RAYp           F2FyR07IdsN7I           1
# 40024     RAYp           F2FyR07IdsN7I           1
# 40034     RAYp           F2FyR07IdsN7I           1
# 40040     RAYp           F2FyR07IdsN7I           1
# 40052     RAYp           F2FyR07IdsN7I           1
#
# [2948 rows x 67 columns]

# %%
data_one_positive.count()
# Out:
# Var6          2948
# Var7          2948
# Var13         2948
# Var21         2948
# Var22         2948
# Var24         2948
# Var25         2948
# Var28         2948
# Var35         2948
# Var38         2948
# Var44         2948
# Var57         2948
# Var65         2948
# Var73         2948
# Var74         2948
# Var76         2948
# Var78         2948
# Var81         2948
# Var83         2948
# Var85         2948
# Var109        2948
# Var112        2948
# Var113        2948
# Var119        2948
# Var123        2948
# Var125        2948
# Var132        2948
# Var133        2948
# Var134        2948
# Var140        2948
#               ...
# Var181        2948
# Var192        2948
# Var193        2948
# Var195        2948
# Var196        2948
# Var197        2948
# Var198        2948
# Var199        2948
# Var202        2948
# Var203        2948
# Var204        2948
# Var205        2948
# Var206        2948
# Var207        2948
# Var208        2948
# Var210        2948
# Var211        2948
# Var212        2948
# Var216        2948
# Var217        2948
# Var218        2948
# Var219        2948
# Var220        2948
# Var221        2948
# Var222        2948
# Var223        2948
# Var226        2948
# ...          ...        ...         ...        ...           ...     ...
# 40019   4.499781   96.97125  224.476595   0.726247  2.579645e+06     ...
# 40020   2.000000   24.00000  220.080000   0.000000  3.155112e+06     ...
# 40021   4.000000   64.00000  253.520000   0.000000  9.309300e+05     ...
# 40022   0.000000   72.00000  166.560000   0.000000  3.435600e+04     ...
# 40023   0.000000    0.00000  220.080000   0.000000  0.000000e+00     ...
# 40025   4.499781   96.97125  224.476595   0.726247  2.579645e+06     ...
# 40026   0.000000   16.00000  220.080000  10.000000  5.184000e+05     ...
# 40027   4.000000   64.00000  233.440000   0.000000  2.603400e+04     ...
# 40028   4.000000  128.00000  238.800000   0.000000  8.513400e+04     ...
# 40029   4.000000   16.00000  253.520000   0.000000  2.597430e+06     ...
# 40030   4.499781   96.97125  224.476595   0.726247  2.579645e+06     ...
# 40031   2.000000   72.00000  262.000000   0.000000  7.773420e+06     ...
# 40032   4.000000   56.00000  510.880000  10.000000  1.359168e+06     ...
# 40033   4.000000  608.00000  553.840000   0.000000  3.212202e+06     ...
# 40035   2.000000  192.00000  166.560000   0.000000  4.320000e+02     ...
# 40036   0.000000    8.00000  113.040000   0.000000  0.000000e+00     ...
# 40037   0.000000    8.00000  186.640000   0.000000  5.605272e+06     ...
# 40038  32.000000  600.00000  133.120000   0.000000  1.528200e+05     ...
# 40039   0.000000    0.00000  220.080000   0.000000  7.257600e+06     ...
# 40041   0.000000   48.00000  340.400000   0.000000  5.261610e+06     ...
# 40042   4.499781    0.00000  133.120000   0.000000  0.000000e+00     ...
# 40043   0.000000   24.00000  234.720000   0.000000  9.795120e+06     ...
# 40044   6.000000  160.00000  181.120000   0.000000  9.313440e+05     ...
# 40045   0.000000   16.00000   31.440000   0.000000  0.000000e+00     ...
# 40046   4.000000   32.00000  301.600000   0.000000  4.920432e+06     ...
# 40047   0.000000   24.00000  186.640000   0.000000  1.715400e+04     ...
# 40048   2.000000   64.00000  253.520000  15.000000  2.848182e+06     ...
# 40049  18.000000  432.00000  336.560000   0.000000  2.214786e+06     ...
# 40050   2.000000   88.00000  166.560000   0.000000  0.000000e+00     ...
# 40051   4.499781   96.97125  224.476595   0.726247  2.579645e+06     ...
#
#        Var218   Var219   Var220   Var221   Var222      Var223  Var226  \
# 0        cJvF     FzaX  1YVfGrO     oslk  fXVEsaq  jySVZNlOJy    xb3V
# 1        cJvF     FzaX  0AJo2f2     oslk  2Kb5FSF  LM8l689qOp    fKCe
# 2        UYBR     FzaX  JFM1BiF  Al6ZaUT  NKv4yOc  jySVZNlOJy    Qu4f
# 3        UYBR     FzaX  L91KIiz     oslk  CE7uk3u  LM8l689qOp    FSa2
# 4        UYBR     FzaX  OrnLfvc     oslk  1J2cvxe  LM8l689qOp    FSa2
# 5        UYBR     FzaX  KbkKEj0     zCkv  QqVuch3  LM8l689qOp    Qcbd
# 6        UYBR     FzaX  U8IKsQe     oslk  R2LdzOv  LM8l689qOp    FSa2
# 7        cJvF     FzaX  ROeipLp     zCkv  K2SqEo9  jySVZNlOJy    PM2D
# 8        UYBR     FzaX  fabLnWA     oslk  EPqQcw6  LM8l689qOp    FSa2
# 9        UYBR     FzaX  4UxGlow     zCkv  catzS2D  LM8l689qOp    WqMG
# 10       UYBR     qxDb  OXxlI5k     oslk  VWtIBQt  LM8l689qOp    FSa2
# 11       cJvF     FzaX  fxJmel6     zCkv  WfsWw2A  LM8l689qOp    me1d
# 12       cJvF     FzaX  WaovEWW     oslk  QKXEsaq  LM8l689qOp    Qu4f
# 14       cJvF     FzaX  XsNOZ4E     oslk  IIvQguc  LM8l689qOp    Qu4f
# 15       UYBR  AU8pNoi  4UxGlow  QKW8DRm  catzS2D  LM8l689qOp    WqMG
# 16       UYBR     qxDb  meWmFX7     oslk  DQ3iZDY  jySVZNlOJy    FSa2
# 17       UYBR     FzaX  6g5Ojel     oslk  UbjqFbB  LM8l689qOp    TNEC
# 18       UYBR     FzaX  b0vOZ4E     oslk  1gu2qo0  LM8l689qOp    FSa2
# 19       UYBR     FzaX  ALC68SY     oslk  9JvQQMs  LM8l689qOp    453m
# 21       UYBR     FzaX  O30mFX7     oslk  IhKskzO  LM8l689qOp    Xa3G
# 22       cJvF     FzaX  LWnfSEp     oslk  CqZz20V  LM8l689qOp    wX53
# 23       cJvF     FzaX  4UxGlow     zCkv  catzS2D  LM8l689qOp    Qu4f
# 25       UYBR     FzaX  ErGY_02     oslk  a4oQQMs  LM8l689qOp    FSa2
# 26       cJvF  AU8pNoi  mTDfR8o     oslk  dEJz4Af  LM8l689qOp    5Acm
# 27       cJvF     FzaX  ACmTklq     oslk  rDbG_aX  LM8l689qOp    453m
# 28       cJvF     FzaX  NI5gmOy  d0EEeJi  zbRHEwz  LM8l689qOp    szEZ
# 29       UYBR     FzaX  1YVfGrO     oslk  fXVEsaq  LM8l689qOp    xb3V
# 30       cJvF     FzaX  URPcqVw  Al6ZaUT  KrlSanL  LM8l689qOp    Aoh3
# 31       cJvF     Lmli  ch2oGfM     zCkv  P6pu4Vl  LM8l689qOp    xb3V
# 33       UYBR     FzaX  13j7k0_  d0EEeJi  S2JrUdI  LM8l689qOp    uWr3
# ...       ...      ...      ...      ...      ...         ...     ...
# 40019    cJvF     FzaX  AuG9eoy     oslk  Kn26Kfh  LM8l689qOp    me1d
# 40020    UYBR     FzaX  54petck     oslk  eEfa_vf  LM8l689qOp    FSa2
# 40021    cJvF     FzaX  UF16siJ     zCkv  APgdzOv  LM8l689qOp    7P5s
# 40022    UYBR     FzaX  75wv48t     oslk  xKQ2fT4  LM8l689qOp    Qu4f
# 40023    UYBR     FzaX  25c7M23  d0EEeJi  xiJ79x1  jySVZNlOJy    Qu4f
# 40025    cJvF     FzaX  LwGVino     oslk  xYH_Q4n  LM8l689qOp    Qu4f
# 40026    cJvF  AU8_WTd  x6Sa63T  Al6ZaUT  v_KeLdZ  jySVZNlOJy    WqMG
# 40027    UYBR     FzaX  4UxGlow  QKW8DRm  catzS2D  jySVZNlOJy    PM2D
# 40028    cJvF     FzaX  4UxGlow     oslk  catzS2D  LM8l689qOp    Qcbd
# 40029    UYBR     FzaX  lbrVHK6     oslk  _sz_44J  LM8l689qOp    fKCe
# 40030    UYBR     FzaX  THMQrGj     oslk  cObaF5M  LM8l689qOp    FSa2
# 40031    UYBR     FzaX  7XCKpA1     oslk  rH0P_83  LM8l689qOp    szEZ
# 40032    UYBR     FzaX  4UxGlow     oslk  catzS2D  LM8l689qOp    Qcbd
# 40033    cJvF     FzaX  MiSOw16     oslk  alU2fT4  LM8l689qOp    453m
# 40035    cJvF     FzaX  4UxGlow     zCkv  catzS2D  LM8l689qOp    kwS7
# 40036    UYBR     FzaX  QMdfc8E     oslk  mh7QQMs  LM8l689qOp    xb3V
# 40037    cJvF     OFWH  4UxGlow     oslk  catzS2D  LM8l689qOp    xb3V
# 40038    cJvF     FzaX  cfcfc8E     oslk  iQJ2C8o  LM8l689qOp    wX53
# 40039    cJvF     FzaX  JptDSPW     oslk  RkjqJRo  LM8l689qOp    7P5s
# 40041    UYBR     FzaX  UF16siJ     zCkv  APgdzOv  LM8l689qOp    WqMG
# 40042    cJvF     FzaX  THMm0jM     oslk  cObCBw5        M_8D    FSa2
# 40043    cJvF     FzaX  i9JuX8Z     oslk  MRPKMwm  jySVZNlOJy    Qu4f
# 40044    UYBR     FzaX  WWmfR8o     oslk  c4R2fT4  LM8l689qOp    TNEC
# 40045    cJvF     FzaX  ylC6pd1     oslk  BULTE6Y  LM8l689qOp    7P5s
# 40046    UYBR     FzaX  82JTbnP     oslk  bIKwXmR  LM8l689qOp    FSa2
# 40047    UYBR     FzaX  TE7A6IW     oslk  E8Sj7qz  jySVZNlOJy    7P5s
# 40048    cJvF     FzaX  OTgQ8OA     oslk  Vo68gbh  LM8l689qOp    fKCe
# 40049    UYBR  AU8pNoi  kH5eMLh     oslk  dclJEx2  LM8l689qOp    xb3V
# 40050    UYBR     FzaX  MMTv4zN     oslk  GfSQowC  LM8l689qOp    FSa2
# 40051    UYBR     FzaX  BV9YlW4     oslk  2fF2Oqu  LM8l689qOp    FSa2
#
#         Var227                  Var228  Conversion
# 0         RAYp           F2FyR07IdsN7I          -1
# 1         RAYp           F2FyR07IdsN7I          -1
# 2      02N6s8f           ib5G6X1eUxUn6          -1
# 3         RAYp           F2FyR07IdsN7I          -1
# 4         RAYp           F2FyR07IdsN7I          -1
# 5      02N6s8f                 Zy3gnGM          -1
# 6         RAYp           F2FyR07IdsN7I          -1
# 7         6fzt  am14IcfM7tWLrUmRT52KtA          -1
# 8         RAYp                 55YFVY9          -1
# 9         ZI9m           ib5G6X1eUxUn6          -1
# 10        RAYp           F2FyR07IdsN7I          -1
# 11        ZI9m              iyHGyLCEkQ          -1
# 12        RAYp           F2FyR07IdsN7I          -1
# 14        RAYp                 55YFVY9          -1
# 15        ZI9m           ib5G6X1eUxUn6          -1
# 16        RAYp           F2FyR07IdsN7I          -1
# 17        RAYp           F2FyR07IdsN7I          -1
# 18        RAYp           F2FyR07IdsN7I          -1
# 19        RAYp           F2FyR07IdsN7I          -1
# 21        RAYp           F2FyR07IdsN7I          -1
# 22        RAYp           F2FyR07IdsN7I          -1
# 23        ZI9m           ib5G6X1eUxUn6          -1
# 25        RAYp           F2FyR07IdsN7I          -1
# 26        RAYp           F2FyR07IdsN7I          -1
# 27        ZI9m           F2FyR07IdsN7I          -1
# 28     nIGXDli           F2FyR07IdsN7I          -1
# 29        RAYp           F2FyR07IdsN7I          -1
# 30     02N6s8f           xwM2aC7IdeMC0          -1
# 31        ZI9m        R4y5gQQWY8OodqDV          -1
# 33     nIGXDli           F2FyR07IdsN7I          -1
# ...        ...                     ...         ...
# 40019     RAYp           F2FyR07IdsN7I          -1
# 40020     RAYp           F2FyR07IdsN7I          -1
# 40021     6fzt           xwM2aC7IdeMC0          -1
# 40022     RAYp           F2FyR07IdsN7I          -1
# 40023  nIGXDli           F2FyR07IdsN7I          -1
# 40025     RAYp           F2FyR07IdsN7I          -1
# 40026  02N6s8f        R4y5gQQWY8OodqDV          -1
# 40027     ZI9m           ib5G6X1eUxUn6          -1
# 40028     ZI9m           ib5G6X1eUxUn6          -1
# 40029     RAYp           F2FyR07IdsN7I          -1
# 40030     RAYp           F2FyR07IdsN7I          -1
# 40031     RAYp           F2FyR07IdsN7I          -1
# 40032     ZI9m                    VjDE          -1
# 40033     RAYp           F2FyR07IdsN7I          -1
# 40035     ZI9m           ib5G6X1eUxUn6          -1
# 40036     RAYp           F2FyR07IdsN7I          -1
# 40037     ZI9m                    VjDE          -1
# 40038     RAYp           F2FyR07IdsN7I          -1
# 40039     RAYp           F2FyR07IdsN7I          -1
# 40041     6fzt           xwM2aC7IdeMC0          -1
# 40042     RAYp                 55YFVY9          -1
# 40043     RAYp           F2FyR07IdsN7I          -1
# 40044     RAYp           F2FyR07IdsN7I          -1
# 40045     RAYp           F2FyR07IdsN7I          -1
# 40046     RAYp           F2FyR07IdsN7I          -1
# 40047     RAYp                 55YFVY9          -1
# 40048     RAYp           F2FyR07IdsN7I          -1
# 40049     RAYp           F2FyR07IdsN7I          -1
# 40050     RAYp                 55YFVY9          -1
# 40051     RAYp           F2FyR07IdsN7I          -1
#
# [37102 rows x 67 columns]

# %%
data_one_negative.count()
# Out:
# Var6          37102
# Var7          37102
# Var13         37102
# Var21         37102
# Var22         37102
# Var24         37102
# Var25         37102
# Var28         37102
# Var35         37102
# Var38         37102
# Var44         37102
# Var57         37102
# Var65         37102
# Var73         37102
# Var74         37102
# Var76         37102
# Var78         37102
# Var81         37102
# Var83         37102
# Var85         37102
# Var109        37102
# Var112        37102
# Var113        37102
# Var119        37102
# Var123        37102
# Var125        37102
# Var132        37102
# Var133        37102
# Var134        37102
# Var140        37102
#               ...
# Var181        37102
# Var192        37102
# Var193        37102
# Var195        37102
# Var196        37102
# Var197        37102
# Var198        37102
# Var199        37102
# Var202        37102
# Var203        37102
# Var204        37102
# Var205        37102
# Var206        37102
# Var207        37102
# Var208        37102
# Var210        37102
# Var211        37102
# Var212        37102
# Var216        37102
# Var217        37102
# Var218        37102
# Var219        37102
# Var220        37102
# Var221        37102
# Var222        37102
# Var223        37102
# Var226        37102
# Var227        37102
# Var228        37102
# Conversion    37102
# Length: 67, dtype: int64
